# %% [markdown]
# #Part 2: Answer a question
# For this part we again load some requird elements of our model. First we bring in the transformers library to use its tokenizer. Then, our finetuned model from the google drive file where we saved it. Pytorch, string and re are also imported.
#
# We set our model to evaluation mode.

# %%
# !pip install transformers 

import torch
import string, re

from google.colab import drive
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

drive.mount('/content/drive')

model = torch.load("/content/drive/MyDrive/NLU/model220123/model.bin",map_location=torch.device('cpu'))
model.eval()

# %% [markdown]
# Then three usefull functions are defined: One to normalize the text, i.e. remove articles, fix the whote space between words, remove punctuation and lowercase the text, one to compute the answer's f1 score, and a third that uses the other two and actually predicts an answer to the given question.

# %%
def normalize_text(s):
    def remove_articles(text):
        regex = re.compile(r"\b(a|an|the)\b", re.UNICODE)
        return re.sub(regex, " ", text)
    def white_space_fix(text):
        return " ".join(text.split())
    def remove_punc(text):
        exclude = set(string.punctuation)
        return "".join(ch for ch in text if ch not in exclude)
    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))


def compute_f1(prediction, truth):
    pred_tokens = normalize_text(prediction).split()
    truth_tokens = normalize_text(truth).split()
  
    # if either the prediction or the truth is no-answer then f1 = 1 if they agree, 0 otherwise
    if len(pred_tokens) == 0 or len(truth_tokens) == 0:
        return int(pred_tokens == truth_tokens)
  
    common_tokens = set(pred_tokens) & set(truth_tokens)
  
    # if there are no common tokens then f1 = 0
    if len(common_tokens) == 0:
        return 0
  
    prec = len(common_tokens) / len(pred_tokens)
    rec = len(common_tokens) / len(truth_tokens)
  
    return 2 * (prec * rec) / (prec + rec)

def give_an_answer(context,query,answer):
    # Predict
    inputs = tokenizer.encode_plus(query, context, return_tensors='pt')
    outputs = model(**inputs)
    answer_start = torch.argmax(outputs[0])  # get the most likely beginning of answer with the argmax of the score
    answer_end = torch.argmax(outputs[1]) + 1 
    prediction = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(inputs['input_ids'][0][answer_start:answer_end]))

    # prediction = predict(context,query)
    # em_score = compute_exact_match(prediction, answer)
    em_score = int(normalize_text(prediction) == normalize_text(answer))
    f1_score = compute_f1(prediction, answer)

    print(f"Question: {query}")
    print(f"Prediction: {prediction}")
    print(f"True Answer: {answer}")
    print(f"EM: {em_score}")
    print(f"F1: {f1_score}")
    print("\n")
    return f1_score

# %%
context = "Batman is a superhero who appears in American comic books published by DC Comics. The character was created by artist Bob Kane and writer Bill Finger, and debuted in the 27th issue of the comic book Detective Comics on March 30, 1939. In the DC Universe continuity, Batman is the alias of Bruce Wayne, a wealthy American playboy, philanthropist, and industrialist who resides in Gotham City."

queries = ["In which comics does Batman appear?", "Who created the character?", "When did Batman debut?"]

answers = ["DC Comics", "Bob Kane", "March 30, 1939"]

for q,a in zip(queries,answers):
  give_an_answer(context,q,a)

# %% [markdown]
# #Part 3: 200 Questions from the squad training set
# We import the squad training set to randomly check 200 questions and their answers.

# %%
# Import the train set and load it

# %%capture
# !mkdir squad
# !wget https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v1.1.json -O squad/train-v1.1.json

from fastai.imports import *

path = Path('squad/train-v1.1.json')

# Open .json file
with open(path, 'rb') as f:
    train_dict = json.load(f)

# %% [markdown]
# This set undergoes the same procedure in order for its data to be extracted from the json file. To make sure that the context/questions/answers triplets are not mixed up, we create a list of dictionaries called triplets, of which we choose 200 in random. Then, we break them back into lists, for them to be used by our model.

# %%
test_contexts  = []
test_questions = []
test_answers   = []

# Search for context, question and answer in each passage and append to respective lists
for group in train_dict['data']:
    for passage in group['paragraphs']:
        context = passage['context']
        for qa in passage['qas']:
            question = qa['question']
            for answer in qa['answers']:
                test_contexts.append(context)
                test_questions.append(question)
                test_answers.append(answer)

# Store information triplets in dictionaries and append to a list to randomize
triplets = []
for c,q,a in zip(test_contexts, test_questions, test_answers):
    instance = {}
    instance['context'] = c
    instance['question'] = q
    instance['answer'] = a
    triplets.append(instance)    
random_set = random.choices(triplets, k=200)

# Separate back to lists to use in give_an_answer function
random_contexts  = []
random_questions = []
random_answers   = []

for i in random_set:
    random_contexts.append(i['context'])
    random_questions.append(i['question'])
    random_answers.append(i['answer'])

# %% [markdown]
# The give_an_answer function is set to return the f1 score it produces, which we use to calculate the mean f1 score for the 200 answers. Here we try it in the first example:`

# %%
f1_score = give_an_answer(random_contexts[0],random_questions[0],random_answers[0]['text'])
print('F1 score:', f1_score)
# Out:
# Question: Which police force in London does not typically engage in police activity with the general public?
# Prediction: which police force
# True Answer: the Ministry of Defence Police
# EM: 0
# F1: 0.28571428571428575
#
#
# F1 score: 0.28571428571428575

# %% [markdown]
# As in Part 2, we use the give_an_answer function to check the answers for the 200 random selections from the training set.

# %%
totalF1 = 0

for c, q, a in zip(random_contexts, random_questions, random_answers):
    f = give_an_answer(c, q, a['text'])
    totalF1 += f

print(totalF1/200)
# Out:
# Question: Which police force in London does not typically engage in police activity with the general public?
# Prediction: which police force
# True Answer: the Ministry of Defence Police
# EM: 0
# F1: 0.28571428571428575
#
#
# Question: About how many cubic kilometers of the vast stock forest's wood were harvested in 1991?
# Prediction: 3. 5
# True Answer: 3.5
# EM: 0
# F1: 0
#
#
# Question: In the 2009 election, who was the candidate of the PAIGC?
# Prediction: sanha
# True Answer: Sanhá
# EM: 0
# F1: 0
#
#
# Question: What was the name of the a cappella musical that first opened 28 January 1994?
# Prediction: avenue x
# True Answer: Avenue X
# EM: 1
# F1: 1.0
#
#
# Question: What political idealogy did Gaddafi not believe in?
# Prediction: arab nationalist activism
# True Answer: factionalism
# EM: 0
# F1: 0
#
#
# Question: What element made Oasis unique among 1990s Britpop bands?
# Prediction:
# True Answer: a hard rock sound
# EM: 0
# F1: 0
#
#
# Question: How did the Methodist movement spread so far and wide?
# Prediction: because of vigorous missionary activity
# True Answer: vigorous missionary activity
# EM: 0
# F1: 0.7499999999999999
#
#
# Question: What are the whimsical alternatives of Palladian architecture?
# Prediction: palladian architecture — and its whimsical alternatives, gothic and chinoiserie
# True Answer: Gothic and Chinoiserie
# EM: 0
# F1: 0.4615384615384615
#
#
# Question: Which form of the phrase is more common in print publications?
# Prediction:
# True Answer: daylight saving time
# EM: 0
# F1: 0
#
#
# Question: Which politican left the presidential race after supporting a boycott by voters?
# Prediction: andre milongo
# True Answer: Milongo
# EM: 0
# F1: 0.6666666666666666
#
#
# Question: How long are females required to go to school?
# Prediction: 10 years for males and 11 years for females ( 2001 ). the adult literacy rate is 99. 0 % ( 2002 ). in 2010, there were 1, 918 students who were taught by 109 teachers ( 98 certified and 11 uncertified ). the teacher - pupil ratio for primary schools in tuvalu is around 1 : 18
# True Answer: 11 years
# EM: 0
# F1: 0.08163265306122448
#
#
# Question: What is the mean high temperature in Guam?
# Prediction: 65 °f
# True Answer: 86 °F (30 °C)
# EM: 0
# F1: 0.3333333333333333
#
#
# Question: What was the primary focus of Bush's campaign?
# Prediction:
# True Answer: national security
# EM: 0
# F1: 0
#
#
# Question: What team of artist and writer helped popularize the Uncanny X-Men line of comics in the 1980s?
# Prediction: jim shooter
# True Answer: Chris Claremont and John Byrne
# EM: 0
# F1: 0
#
#
# Question: According to Paul VI  to whom are a  man and woman in union with besides each other?
# Prediction:
# True Answer: God
# EM: 0
# F1: 0
#
#
# Question: What groups are called Vlachs?
# Prediction: muslim
# True Answer: Aromanians and Moglenites
# EM: 0
# F1: 0
#
#
# Question: What is the rank of Hyderabad among cities contributing to India's GDP?
# Prediction: fifth
# True Answer: fifth-largest
# EM: 0
# F1: 0
#
#
# Question: What variety of Islam was Gaddafi raised in?
# Prediction: sunni branch
# True Answer: Sunni
# EM: 0
# F1: 0.6666666666666666
#
#
# Question: The electronic transition frequency of which element defines the second?
# Prediction: international unit of time
# True Answer: caesium atoms
# EM: 0
# F1: 0
#
#
# Question: What is the average temperature of the Earth's surface in Celsius?
# Prediction:
# True Answer: 14
# EM: 0
# F1: 0
#
#
# Question: What did the gaelic root of the word for God mean?
# Prediction: to call " or " to invoke
# True Answer: "to call" or "to invoke"
# EM: 1
# F1: 0.8000000000000002
#
#
# Question: What are the colors of traffic lights in Japan?
# Prediction:
# True Answer: the same colors that other countries have
# EM: 0
# F1: 0
#
#
# Question: When did British troops occupy the city of Montevideo?
# Prediction:
# True Answer: 3 February 1807
# EM: 0
# F1: 0
#
#
# Question: What did Huxley's 1860 article in the Westminster Review promote?
# Prediction: secular, without religious interference, and his article in the april 1860 westminster review promoted scientific naturalism over natural theology, praising darwin for " extending the domination of science over regions of thought into which she has, as yet, hardly penetrated " and coining the term " darwinism " as part of his efforts to secularise and professionalise science. huxley gained influence, and initiated the x club, which used the journal nature to promote evolution and naturalism, shaping much of late victorian science. later, the german morphologist ernst haeckel would convince huxley that comparative anatomy and palaeontology could be used to reconstruct evolutionary genealogies
# True Answer: scientific naturalism over natural theology
# EM: 0
# F1: 0.10204081632653061
#
#
# Question: What term came into use in Victorian times to designate the pub landlord?
# Prediction: pub landlord
# True Answer: publican
# EM: 0
# F1: 0
#
#
# Question: What was Triangle Transit called before?
# Prediction: triangle transit
# True Answer: Triangle Transit Authority,
# EM: 0
# F1: 0.8
#
#
# Question: What was the first fossil to display both clearly traditional reptilian characteristics?
# Prediction: archaeopteryx
# True Answer: Archaeopteryx
# EM: 1
# F1: 1.0
#
#
# Question: Did the CAFS accelerator work as planned?
# Prediction:
# True Answer: efforts were generally unsuccessful
# EM: 0
# F1: 0
#
#
# Question: In what body gland are the peripheral oscillators located?
# Prediction: adrenal gland
# True Answer: adrenal gland
# EM: 1
# F1: 1.0
#
#
# Question: What other divisions can be made of dialects?
# Prediction:
# True Answer: subdialects
# EM: 0
# F1: 0
#
#
# Question: What type of government did Espartero have?
# Prediction: progressive
# True Answer: progressive
# EM: 1
# F1: 1.0
#
#
# Question: What did Mildred Burke form?
# Prediction: world women's wrestling association
# True Answer: Women's Wrestling Association
# EM: 0
# F1: 0.8571428571428571
#
#
# Question: What were the consequences of John William Bean's attempt to fire at the Queen?
# Prediction: gun did not fire ; he escaped. the following day, victoria drove the same route, though faster and with a greater escort, in a deliberate attempt to provoke francis to take a second aim and catch him in the act. as expected, francis shot at her, but he was seized by plain - clothes policemen, and convicted of high treason. on 3 july, two days after francis's death sentence was commuted to transportation for life, john william bean also tried to fire a pistol at the queen, but it was loaded only with paper and tobacco and had too little charge. edward oxford felt that the attempts were encouraged by his acquittal in 1840. bean was sentenced to 18 months in jail. in a similar attack in 1849, unemployed irishman william hamilton fired a powder - filled pistol at victoria's carriage as it passed along constitution hill, london. in 1850, the queen did sustain injury when she was assaulted by a possibly insane ex - army officer, robert pate. as victoria was riding in a carriage, pate struck her with his cane, crushing her bonnet and bruising her forehead
# True Answer: 18 months in jail
# EM: 0
# F1: 0.045714285714285714
#
#
# Question: On what fault did the earthquake occur?
# Prediction: longmenshan fault
# True Answer: Longmenshan fault
# EM: 1
# F1: 1.0
#
#
# Question: Who did Nasser recruit to be Prime Minister?
# Prediction: ali maher
# True Answer: Ali Maher
# EM: 1
# F1: 1.0
#
#
# Question: What does the definition of essential genes assume an absence of?
# Prediction: environmental stress
# True Answer: environmental stress
# EM: 1
# F1: 1.0
#
#
# Question: Who assumed total control of Egypt?
# Prediction: communists, and the dismissal of 140 officers loyal to naguib
# True Answer: Nasser
# EM: 0
# F1: 0
#
#
# Question: How much of Pakistan's GDP came from Punjab in 2000?
# Prediction:
# True Answer: 54.7%
# EM: 0
# F1: 0
#
#
# Question: What is the range of perceptible pitch steps to human hearing?
# Prediction:
# True Answer: 1,400
# EM: 0
# F1: 0
#
#
# Question: What is the biological interaction where a predator feeds on its prey called?
# Prediction: detritivory
# True Answer: Predation
# EM: 0
# F1: 0
#
#
# Question: When did Ahmad fight at Balakot?
# Prediction: 1831
# True Answer: 1831
# EM: 1
# F1: 1.0
#
#
# Question: What kind of engineering does industry in Southampton support?
# Prediction: older industries of the docks
# True Answer: electrical
# EM: 0
# F1: 0
#
#
# Question: Who advised Vicotria to begin appaering in public?
# Prediction: victoria's self - imposed isolation from the public diminished the popularity of the monarchy, and encouraged the growth of the republican movement. she did undertake her official government duties, yet chose to remain secluded in her royal residences — windsor castle, osborne house, and the private estate in scotland that she and albert had acquired in 1847, balmoral castle. in march 1864, a protester stuck a notice on the railings of buckingham palace that announced " these commanding premises to be let or sold in consequence of the late occupant's declining business ". her uncle leopold
# True Answer: Her uncle Leopold
# EM: 0
# F1: 0.06976744186046512
#
#
# Question: In what years was Cyprus divided?
# Prediction: 1965
# True Answer: 1974
# EM: 0
# F1: 0
#
#
# Question: What can be used to balance out a portion of the energy used by HVAC systems?
# Prediction: solar heating, cooling and ventilation technologies
# True Answer: Solar heating, cooling and ventilation technologies
# EM: 1
# F1: 1.0
#
#
# Question: How many judges and prosecutors does Portugal have per 100,000 inhabitants?
# Prediction: slow and inefficient
# True Answer: over 30
# EM: 0
# F1: 0
#
#
# Question: Which one of Madonna's movie is a box office bomb?
# Prediction:
# True Answer: Swept Away
# EM: 0
# F1: 0
#
#
# Question: Where was the expansion of cotton and agriculture mainly?
# Prediction: southern region
# True Answer: in the southern region
# EM: 0
# F1: 0.8
#
#
# Question: What year was Victorien Sardou's Madame Sans-Gêne written?
# Prediction: 2005
# True Answer: 1893
# EM: 0
# F1: 0
#
#
# Question: What did Phoenicans name their settlement in 734BC?
# Prediction: straight road
# True Answer: "Ziz."
# EM: 0
# F1: 0
#
#
# Question: Under who did Areminia become fully sovereign?
# Prediction:
# True Answer: King Artaxias I
# EM: 0
# F1: 0
#
#
# Question: With what iOS release did Apple standardize media apps on all their products?
# Prediction: iphone and ipad
# True Answer: iOS 5
# EM: 0
# F1: 0
#
#
# Question: When was Queen Victoria's funeral held?
# Prediction:
# True Answer: 2 February
# EM: 0
# F1: 0
#
#
# Question: What color LED was demonstrated in 1994?
# Prediction: blue
# True Answer: blue
# EM: 1
# F1: 1.0
#
#
# Question: What is the oldest public high school in the US?
# Prediction: the boston latin school
# True Answer: The Boston Latin School
# EM: 1
# F1: 1.0
#
#
# Question: What concept does the government currently support for education?
# Prediction: school choice
# True Answer: specialisation
# EM: 0
# F1: 0
#
#
# Question: What style does most of the city's architecture belong to?
# Prediction: georgian
# True Answer: Georgian
# EM: 1
# F1: 1.0
#
#
# Question: Are any relatives of the first people of  the Grecian world still around ?
# Prediction:
# True Answer: there are still communities in Pakistan and Afghanistan, like the Kalash, who claim to be descended from Greek settlers.
# EM: 0
# F1: 0
#
#
# Question: When did Paul Ehrenfest come up with the name "ultraviolet catastrophe"?
# Prediction: 1911
# True Answer: 1911
# EM: 1
# F1: 1.0
#
#
# Question: Hound became the term for dogs who did what activity during this time?
# Prediction: hunting
# True Answer: hunting
# EM: 1
# F1: 1.0
#
#
# Question: What dictates passenger elevator capacities?
# Prediction: passenger elevators
# True Answer: the available floor space
# EM: 0
# F1: 0
#
#
# Question: Who was the Mongol prince?
# Prediction:
# True Answer: Godan
# EM: 0
# F1: 0
#
#
# Question: What identifier allows a player to activate a PlayStation 3?
# Prediction: playstation network id
# True Answer: PlayStation Network ID
# EM: 1
# F1: 1.0
#
#
# Question: What is sexual orientation defined as?
# Prediction: sexual identity referring to an individual's conception of themselves, behavior referring to actual sexual acts performed by the individual, and orientation referring to " fantasies, attachments and longings
# True Answer: fantasies, attachments and longings
# EM: 0
# F1: 0.2758620689655173
#
#
# Question: In which region of Portugal did the Muslim population stay?
# Prediction: portugal
# True Answer: Algarve region, and south of the Tagus
# EM: 0
# F1: 0
#
#
# Question: Which platform did Internet Archive adopt in 2009?
# Prediction: open storage
# True Answer: Sun Open Storage
# EM: 0
# F1: 0.8
#
#
# Question: What viewpoint have scholars translated and analyzed documents to writes histories from?
# Prediction: latin letters
# True Answer: indigenous
# EM: 0
# F1: 0
#
#
# Question: When was the first year that clubs threatened to leave the Football League?
# Prediction: 1988
# True Answer: 1988
# EM: 1
# F1: 1.0
#
#
# Question: Does Myanmar offer any destinations  that might be good for outside enthusiasts ?
# Prediction:
# True Answer: nature trails in Inle Lake, Kengtung, Putao, Pyin Oo Lwin
# EM: 0
# F1: 0
#
#
# Question: Who attempted to assassinate the Queen?
# Prediction: roderick maclean
# True Answer: Roderick Maclean
# EM: 1
# F1: 1.0
#
#
# Question: What caused alarm in France?
# Prediction: what caused alarm in france? [SEP] in april 1758, the british concluded the anglo - prussian convention with frederick in which they committed to pay him an annual subsidy of £670, 000. britain also dispatched 9, 000 troops to reinforce ferdinand's hanoverian army, the first british troop commitment on the continent and a reversal in the policy of pitt. ferdinand had succeeded in driving the french from hanover and westphalia and re - captured the port of emden in march 1758 before crossing the rhine with his own forces, which caused alarm in france. despite ferdinand's victory over the french at the battle of krefeld and the brief occupation of dusseldorf, he was compelled by the successful manoeuvering of larger french forces to withdraw across the rhine
# True Answer: re-captured the port of Emden in March 1758 before crossing the Rhine with his own forces
# EM: 0
# F1: 0.2096774193548387
#
#
# Question: When was the Yerevan demonstration?
# Prediction: october 17, 1987
# True Answer: October 17, 1987
# EM: 1
# F1: 1.0
#
#
# Question: What instrument did Chopin play for Charles Hallé when the latter visited him?
# Prediction:
# True Answer: piano
# EM: 0
# F1: 0
#
#
# Question: What is one of the major problems with the economy in November 2008?
# Prediction:
# True Answer: loss of close to $6 trillion in housing wealth
# EM: 0
# F1: 0
#
#
# Question: For what length of time can a dead lower limb stay attached to a tree?
# Prediction: years
# True Answer: years
# EM: 1
# F1: 1.0
#
#
# Question: What law made Valencia the capital of its region?
# Prediction: valencian community
# True Answer: Statute of Autonomy
# EM: 0
# F1: 0
#
#
# Question: Which country did Iraq invade in 1990?
# Prediction: germany
# True Answer: Kuwait
# EM: 0
# F1: 0
#
#
# Question: Who developed the first mnotor capable of being used for machinery?
# Prediction:
# True Answer: William Sturgeon
# EM: 0
# F1: 0
#
#
# Question: Who owned the Detroit Drive in this period?
# Prediction: mike ilitch
# True Answer: Mike Ilitch
# EM: 1
# F1: 1.0
#
#
# Question: Who first used the term Iranian language?
# Prediction:
# True Answer: Christian Lassen
# EM: 0
# F1: 0
#
#
# Question: What happens when a doctor doesn't know the microorganism yet?
# Prediction: empirical therapy
# True Answer: broad spectrum antibiotic
# EM: 0
# F1: 0
#
#
# Question: During what time period did the Albigensian Crusade occur?
# Prediction: 1209 – 1229
# True Answer: 1209–1229
# EM: 0
# F1: 0
#
#
# Question: Where did young Nasser witness demonstrations?
# Prediction: alexandria
# True Answer: Manshia Square
# EM: 0
# F1: 0
#
#
# Question: What can visceral pain be accompanied by?
# Prediction: nausea and vomiting
# True Answer: nausea and vomiting
# EM: 1
# F1: 1.0
#
#
# Question: What age groups are usually enrolled in madaris?
# Prediction:
# True Answer: all ages
# EM: 0
# F1: 0
#
#
# Question: When did a royal expedition to enforce agreements occur?
# Prediction: 1204 and 1211
# True Answer: 1211
# EM: 0
# F1: 0.5
#
#
# Question: Where is the GDP of Thuringia?
# Prediction: below the national average, in line with the other former east german lands. until 2004, thuringia was one of the weakest regions within the european union. the accession of several new countries, the crisis in southern europe and the sustained economic growth in germany since 2005 has brought the thuringian gdp close to the eu average
# True Answer: below the national average
# EM: 0
# F1: 0.12
#
#
# Question: The Supreme Leader appoints how many members of the Guardian Council?
# Prediction: twelve
# True Answer: six
# EM: 0
# F1: 0
#
#
# Question: France was angered by Nasser's support of the independence of what people?
# Prediction: france
# True Answer: Algerian
# EM: 0
# F1: 0
#
#
# Question: What might chronic pain sometimes be referred to as?
# Prediction: cancer pain or else as benign
# True Answer: cancer pain
# EM: 0
# F1: 0.5
#
#
# Question: What was responsible for the drop in Apple's margins in 1989?
# Prediction: ms - dos
# True Answer: a component shortage
# EM: 0
# F1: 0
#
#
# Question: What is the annual mean temperature of New Delhi?
# Prediction: humid subtropical climate
# True Answer: 25 °C (77 °F)
# EM: 0
# F1: 0
#
#
# Question: What new technology is being used in teh vaccine making process that will make vaccines safer and eaier for most consumers?
# Prediction: bacteria can be grown in the laboratory on nutrient culture media, but viruses need living cells in which to replicate. many vaccines to infectious diseases can be grown in fertilised chicken eggs. millions of eggs are used each year to generate the annual flu vaccine requirements
# True Answer: . Cell-based culture
# EM: 0
# F1: 0.04347826086956522
#
#
# Question: Which mountain range contains Mount Whitney?
# Prediction: mount whitney
# True Answer: Sierra Nevada
# EM: 0
# F1: 0
#
#
# Question: What body of water is Valencia located on?
# Prediction: 5th busiest container port in europe and the busiest container port on the mediterranean sea
# True Answer: the Mediterranean Sea
# EM: 0
# F1: 0.2666666666666667
#
#
# Question: What television show uses a dominance model of dog and human relationships?
# Prediction: dog whisperer
# True Answer: Dog Whisperer.
# EM: 1
# F1: 1.0
#
#
# Question: What is the name of the route that heads north of downtown?
# Prediction: u. s. route 1
# True Answer: Whalley Avenue
# EM: 0
# F1: 0
#
#
# Question: To which pope can the Evangelium Vitae be attributed to?
# Prediction: edouard gagnon
# True Answer: Pope John Paul II
# EM: 0
# F1: 0
#
#
# Question: NYC's fashion industry employs how many people?
# Prediction:
# True Answer: 180,000
# EM: 0
# F1: 0
#
#
# Question: With what type of facade were buildings left with if they were to completed at a later time?
# Prediction: brick gothic
# True Answer: undecorated façade
# EM: 0
# F1: 0
#
#
# Question: Which pole is located in Antarctica?
# Prediction: ænˈtɑːtɪkə / or / ænˈɑːtɪkə /
# True Answer: South Pole
# EM: 0
# F1: 0
#
#
# Question: Which directions does the South Saharan run?
# Prediction: east and west
# True Answer: east and west
# EM: 1
# F1: 1.0
#
#
# Question: What fighting formation would eventually replace the phalanx in battle?
# Prediction: manipular
# True Answer: manipular formation
# EM: 0
# F1: 0.6666666666666666
#
#
# Question: In history, where could you find someone studying politics?
# Prediction: every geographic area
# True Answer: in almost every geographic area
# EM: 0
# F1: 0.7499999999999999
#
#
# Question: What does federations have for amendments of the constitution?
# Prediction: three - quarters
# True Answer: special procedures
# EM: 0
# F1: 0
#
#
# Question: In the United States the term "black people" is an indicator for?
# Prediction: white if they fulfill other social criteria of " whiteness
# True Answer: socially based racial classification related to being African American,
# EM: 0
# F1: 0
#
#
# Question: The Army will be keeping 5,681 of what vehicle?
# Prediction: army will keep, 5, 036
# True Answer: Oshkosh M-ATV
# EM: 0
# F1: 0
#
#
# Question: On which date is the annual Republic Day parade held in New Delhi?
# Prediction: 26 january
# True Answer: 26 January
# EM: 1
# F1: 1.0
#
#
# Question: What is the theoretical LER value of tungsten at its melting point?
# Prediction:
# True Answer: 52 lumens per watt
# EM: 0
# F1: 0
#
#
# Question: White LEDs can be made by coating what?
# Prediction:
# True Answer: near-ultraviolet (NUV) LEDs
# EM: 0
# F1: 0
#
#
# Question: Who was Philip II planning a campaign against when he was assasinated?
# Prediction:
# True Answer: Achaemenid Empire of Persia
# EM: 0
# F1: 0
#
#
# Question: How is it determined, which cells will be formed?
# Prediction: epigenetic changes in eukaryotic biology serve to regulate the process of cellular differentiation. during morphogenesis, totipotent stem cells become the various pluripotent cell lines of the embryo, which in turn become fully differentiated cells. a single fertilized egg cell, the zygote, gives rise to the many different plant cell types including parenchyma, xylem vessel elements, phloem sieve tubes, guard cells of the epidermis, etc. as it continues to divide. the process results from the epigenetic activation of some genes and inhibition of others
# True Answer: activation of some genes and inhibition of others
# EM: 0
# F1: 0.17073170731707316
#
#
# Question: Under what government system does Miami operate?
# Prediction: mayor - commissioner type of system
# True Answer: mayor-commissioner
# EM: 0
# F1: 0
#
#
# Question: What was the name of the non-subscription Xbox online gaming service?
# Prediction: xbox live was shut down for 24 hours and underwent a major upgrade, adding a basic non - subscription service called xbox live silver
# True Answer: Xbox Live Silver
# EM: 0
# F1: 0.25
#
#
# Question: What is constitutionally forbidden to be established in the state of Georgia?
# Prediction: no person within this state shall, upon any pretense, be deprived of the inestimable privilege of worshipping god in any manner agreeable to his own conscience, nor be compelled to attend any place of worship
# True Answer: No one religious society
# EM: 0
# F1: 0.05263157894736842
#
#
# Question: How much did Schwarzenegger make from the film Total Recall, on top of 15% of gross?
# Prediction: $ 10 million and 15 %
# True Answer: $10 million
# EM: 0
# F1: 0.6666666666666666
#
#
# Question: Who did Kerry criticize during the 2004 campaign?
# Prediction: kerry
# True Answer: President George W. Bush
# EM: 0
# F1: 0
#
#
# Question: What rivers form the Missouri River?
# Prediction: jefferson, madison and gallatin rivers
# True Answer: Jefferson, Madison and Gallatin rivers
# EM: 1
# F1: 1.0
#
#
# Question: Since 1976, how many Americans have been executed for crimes committed as juveniles?
# Prediction:
# True Answer: Twenty-two
# EM: 0
# F1: 0
#
#
# Question: What nationality was Evlija Chelebija?
# Prediction: macedonian
# True Answer: Turkish
# EM: 0
# F1: 0
#
#
# Question: When did the SSA open its largest videoconferencing-only center?
# Prediction: 2009
# True Answer: August 2010
# EM: 0
# F1: 0
#
#
# Question: What does a team do when they have not advance the ball enough to score or likely gain a new set of downs?
# Prediction: advance the ball at least ten yards towards the opponents'goal line
# True Answer: punt
# EM: 0
# F1: 0
#
#
# Question: Basic respect for human beings is known as what?
# Prediction: what
# True Answer: "Kavod Habriyot"
# EM: 0
# F1: 0
#
#
# Question: Who stated that God was difficult both to prove or disprove?
# Prediction: carl sagan
# True Answer: Carl Sagan
# EM: 1
# F1: 1.0
#
#
# Question: What government position was held by the man who donated the Grey Cup to Canadian football?
# Prediction: governor general of canada
# True Answer: The Governor General of Canada
# EM: 1
# F1: 1.0
#
#
# Question: Where did Stein graduate from?
# Prediction: bronx
# True Answer: the Bronx High School of Science
# EM: 0
# F1: 0.33333333333333337
#
#
# Question: With out the letters of marque what wepon did  they have to protect themself that was a part of their ship?
# Prediction:
# True Answer: cannon
# EM: 0
# F1: 0
#
#
# Question: An argument against affirmative action is that it encourages what?
# Prediction:
# True Answer: mediocrity and incompetence
# EM: 0
# F1: 0
#
#
# Question: In what year was lordship of the Isle of Man purchased?
# Prediction: 1765
# True Answer: 1765
# EM: 1
# F1: 1.0
#
#
# Question: When was the first widely used version of USB released?
# Prediction: september 1998
# True Answer: September 1998
# EM: 1
# F1: 1.0
#
#
# Question: How much of the Thuringia population is non-religious?
# Prediction: over two thirds
# True Answer: Today over two thirds of the population
# EM: 0
# F1: 0.6666666666666666
#
#
# Question: What is Paul Heinegg?
# Prediction:
# True Answer: scholar
# EM: 0
# F1: 0
#
#
# Question: What is the Michigan Stadium called colloquially?
# Prediction: the big house
# True Answer: The Big House
# EM: 1
# F1: 1.0
#
#
# Question: Who is the president of the regional counsel?
# Prediction: philippe richert
# True Answer: Philippe Richert
# EM: 1
# F1: 1.0
#
#
# Question: What was his second proposition?
# Prediction: infants are not to be baptized
# True Answer: Antichristians converted are to be admitted into the true Church by baptism
# EM: 0
# F1: 0.3529411764705882
#
#
# Question: How many miles are between Alaska and Washington state?
# Prediction: 500
# True Answer: 500
# EM: 1
# F1: 1.0
#
#
# Question: In what fields did achievements occur during the revolution?
# Prediction: electrification to developments in materials science
# True Answer: electrification to developments in materials science.
# EM: 1
# F1: 1.0
#
#
# Question: When did China formally ask for help from the international community?
# Prediction: may 14
# True Answer: May 14
# EM: 1
# F1: 1.0
#
#
# Question: How many 400+ foot skyscrapers have been built or are in the process of being built in Miami since 2001?
# Prediction: eight
# True Answer: 50
# EM: 0
# F1: 0
#
#
# Question: Lenin acknowledged the independence of which countries?
# Prediction: bolsheviks
# True Answer: Finland, Estonia, Latvia, Lithuania and Poland.
# EM: 0
# F1: 0
#
#
# Question: How many of New York's boroughs would be counted among the United States' ten most populated cities if they were independent?
# Prediction: four
# True Answer: four
# EM: 1
# F1: 1.0
#
#
# Question: Who was the first clubs have won the fa cup as part of a league cup double?
# Prediction: arsenal
# True Answer: Preston North End (1889)
# EM: 0
# F1: 0
#
#
# Question: In what year did the National Assembly support a crucial bill about "self Management"?
# Prediction: 1950
# True Answer: 1950
# EM: 1
# F1: 1.0
#
#
# Question: In what areas of philosophy did Hume become a major figure?
# Prediction: virtue
# True Answer: skeptical philosophical and empiricist traditions
# EM: 0
# F1: 0
#
#
# Question: Who goaded the French into war by editing a telegram sent by William I?
# Prediction: otto von bismarck
# True Answer: Otto von Bismarck
# EM: 1
# F1: 1.0
#
#
# Question: What percent of the population are between 14 to 30 years old?
# Prediction: uzbeks and russians
# True Answer: 35%
# EM: 0
# F1: 0
#
#
# Question: What aspect of the PS3 Slim was CNET unhappy was missing for PS2 games?
# Prediction: lack of backward compatibility
# True Answer: backward compatibility
# EM: 0
# F1: 0.6666666666666666
#
#
# Question: What is mechanical potential energy?
# Prediction: elastic potential energy in rocks
# True Answer: elastic strain
# EM: 0
# F1: 0.28571428571428575
#
#
# Question: In what area of Greenland can glaciers move 20-30m per day?
# Prediction: greenland
# True Answer: Jakobshavn Isbræ
# EM: 0
# F1: 0
#
#
# Question: What is another term for legal adulthood?
# Prediction: adolescence
# True Answer: age of majority
# EM: 0
# F1: 0
#
#
# Question: How many more states aside from California does the interstate 10 run through?
# Prediction: seven
# True Answer: seven more
# EM: 0
# F1: 0.6666666666666666
#
#
# Question: What happened in the European Union in 1996?
# Prediction:
# True Answer: agreed to a number of exceptions for young people in its child labour laws
# EM: 0
# F1: 0
#
#
# Question: What type of clothing does Parkwood Topshop Athletic Ltd produce?
# Prediction: athletic, street wear
# True Answer: activewear
# EM: 0
# F1: 0
#
#
# Question: Which historian counters criticism of Napoleon by suggesting that the wars he fought were the responsibility of enemies of the Revolution, rather than that of Napoleon?
# Prediction: enemies of the revolution, rather than that of napoleon? [SEP] critics argue napoleon's true legacy must reflect the loss of status for france and needless deaths brought by his rule : historian victor davis hanson
# True Answer: Vincent Cronin
# EM: 0
# F1: 0
#
#
# Question: What American holiday is Carnival celebrated on?
# Prediction: west indian day parade or west indian day carnival
# True Answer: Labor Day
# EM: 0
# F1: 0.1818181818181818
#
#
# Question: When were ski-lifts built in Swiss and Austrian towns?
# Prediction: during the post - world war i period
# True Answer: post-World War I
# EM: 0
# F1: 0.4444444444444444
#
#
# Question: What influences water evaporation on leaves?
# Prediction: water evaporation on leaves? [SEP] particularly since the mid - 1960s there have been advances in understanding of the physics of plant physiological processes such as transpiration
# True Answer: temperature
# EM: 0
# F1: 0
#
#
# Question: In what year did a number of events push renewable energy up the political agenda?
# Prediction: 2006
# True Answer: 2006
# EM: 1
# F1: 1.0
#
#
# Question: Which direction does I-19 run from Tucson?
# Prediction: south
# True Answer: south
# EM: 1
# F1: 1.0
#
#
# Question: How long was the GameCube version of Twilight Princess delayed?
# Prediction: month
# True Answer: a month
# EM: 1
# F1: 1.0
#
#
# Question: Who is the market strategist that believes distinctions exist between the current crisis and the Great Depression?
# Prediction: dow
# True Answer: Phil Dow
# EM: 0
# F1: 0.6666666666666666
#
#
# Question: What programs created by FDR helped North Carolina during the Great Depression?
# Prediction: durham
# True Answer: New Deal programs
# EM: 0
# F1: 0
#
#
# Question: Which view treats intellectual property as another type of "real" property?
# Prediction: real " property
# True Answer: absolute protection or full value
# EM: 0
# F1: 0
#
#
# Question: In addition to the original thirteen, which two states were admitted to the union before Tennessee?
# Prediction: vermont
# True Answer: Vermont and Kentucky
# EM: 0
# F1: 0.5
#
#
# Question: After lumbering, what was Seattle's second big economic boom?
# Prediction: second and most dramatic boom and bust resulted from the klondike gold rush
# True Answer: Klondike Gold Rush
# EM: 0
# F1: 0.4
#
#
# Question: How many finalists were there on season eight of American Idol?
# Prediction: 13
# True Answer: 13
# EM: 1
# F1: 1.0
#
#
# Question: Which event precipitated the Ordovician period?
# Prediction: cambrian - ordovician extinction events
# True Answer: the Cambrian-Ordovician extinction
# EM: 0
# F1: 0.3333333333333333
#
#
# Question: Who added the election of laymen to church government?
# Prediction: luther's doctrine of the priesthood of all believers upgraded the role of laymen in the church considerably. the members of a congregation had the right to elect a minister and, if necessary, to vote for his dismissal
# True Answer: Calvin
# EM: 0
# F1: 0
#
#
# Question: What term describes the nature of how the university is partially funded?
# Prediction:
# True Answer: state-sponsored
# EM: 0
# F1: 0
#
#
# Question: What position is the gymnast when in the air?
# Prediction: standing position
# True Answer: a standing position
# EM: 1
# F1: 1.0
#
#
# Question: What was showered along the route in some places?
# Prediction: half - day holiday for the only latin american stop on the flame's five - continent journey
# True Answer: confetti
# EM: 0
# F1: 0
#
#
# Question: What happens to multiple cup winners?
# Prediction: reception
# True Answer: the trophy was to be permanently presented to any club which won the competition three times,
# EM: 0
# F1: 0
#
#
# Question: What percentage of the student body of BYU has some proficiency in a second language?
# Prediction: 45 percent
# True Answer: Over three quarters
# EM: 0
# F1: 0
#
#
# Question: In what year did Comcast take over a majority interest in QVC?
# Prediction: 1994
# True Answer: 1994
# EM: 1
# F1: 1.0
#
#
# Question: What piece by Mozart is used as a cliche to convey refinement?
# Prediction: bach´s cello suite no. 1
# True Answer: Eine kleine Nachtmusik
# EM: 0
# F1: 0
#
#
# Question: What building was first used for classes at Washington University?
# Prediction: benton school building
# True Answer: Benton School building.
# EM: 1
# F1: 1.0
#
#
# Question: When was the National Government of China moved to Chungking?
# Prediction:
# True Answer: A few days before the fall of the city
# EM: 0
# F1: 0
#
#
# Question: What does the climate of Antarctica inhibit?
# Prediction: plant growth
# True Answer: plant growth
# EM: 1
# F1: 1.0
#
#
# Question: What conferences became a requirement after Vatican II?
# Prediction: national bishop conferences
# True Answer: National Bishop Conferences
# EM: 1
# F1: 1.0
#
#
# Question: What city was the center of the Casas Grandes civilization?
# Prediction: paquime
# True Answer: Paquime
# EM: 1
# F1: 1.0
#
#
# Question: Were utilities publically or privately owned in Menzie's economy?
# Prediction: national party
# True Answer: publicly
# EM: 0
# F1: 0
#
#
# Question: When did Weiss and Cropanzano publish their work?
# Prediction: 2005
# True Answer: 1996
# EM: 0
# F1: 0
#
#
# Question: How did hunters obliterate the advantage bestowed upon the oryx by evolution?
# Prediction:
# True Answer: use of automobiles and high-powered rifles
# EM: 0
# F1: 0
#
#
# Question: Why do birds migrate south in winter?
# Prediction: leave for areas further south ( including the southern hemisphere ) to overwinter
# True Answer: food becomes scarce
# EM: 0
# F1: 0
#
#
# Question: What does VLW stand for?
# Prediction: railroad and road junction and production center
# True Answer: United light metal works
# EM: 0
# F1: 0
#
#
# Question: Where was the Baghdad Railway Suppose to connect?
# Prediction: baghdad railway which was planned to connect the ottoman empire cities of konya and baghdad
# True Answer: Ottoman Empire cities of Konya and Baghdad with a line through modern-day Turkey, Syria and Iraq
# EM: 0
# F1: 0.4827586206896552
#
#
# Question: For what did the Federal forces remain in Charleston?
# Prediction: freed slaves
# True Answer: city's reconstruction
# EM: 0
# F1: 0
#
#
# Question: Oklahoma was the only state where which presidential candidate won no counties twice?
# Prediction: oklahoma
# True Answer: Barack Obama
# EM: 0
# F1: 0
#
#
# Question: What major symptom other than heart problems did beriberi cause?
# Prediction: heart problems and paralysis
# True Answer: paralysis
# EM: 0
# F1: 0.4
#
#
# Question: What philosophy is closely related to process philosophy?
# Prediction: american pragmatism
# True Answer: American pragmatism
# EM: 1
# F1: 1.0
#
#
# Question: What percentage of high-density penetrators is not made up of depleted uranium?
# Prediction: 1 – 2 %
# True Answer: 1–2%
# EM: 0
# F1: 0
#
#
# Question: Which people would Mohammad's critics have compared him to at the time?
# Prediction: sahih al - bukhari narrates muhammad describing the revelations as, " sometimes it is ( revealed ) like the ringing of a bell " and aisha
# True Answer: a possessed man, a soothsayer or a magician
# EM: 0
# F1: 0
#
#
# Question: What are the parts that merged into the Canadian Joint Operations Command?
# Prediction: resources, roles and responsibilities of the three former commands under a single headquarters
# True Answer: Canada Command, the Canadian Expeditionary Force Command and the Canadian Operational Support Command
# EM: 0
# F1: 0.09090909090909091
#
#
# Question: What happened to the usurping bishop, George?
# Prediction: flung into prison and murdered
# True Answer: flung into prison and murdered
# EM: 1
# F1: 1.0
#
#
# Question: Who was possibly the first to use the term "energy" instead of vis viva?
# Prediction:
# True Answer: Thomas Young
# EM: 0
# F1: 0
#
#
# Question: What did the World Economic Forum's Global Competetiveness Report Rank Switzerland's economy as?
# Prediction: most competitive
# True Answer: the most competitive in the world
# EM: 0
# F1: 0.6666666666666666
#
#
# Question: Beyonce's first number one song was which song?
# Prediction:
# True Answer: Crazy in Love
# EM: 0
# F1: 0
#
#
# Question: Which Hawaiin volcano has been erupting since 1983?
# Prediction: hawaiin volcano
# True Answer: Kilauea
# EM: 0
# F1: 0
#
#
# Question: Where did the oldest Portuguese university relocate to?
# Prediction: coimbra
# True Answer: Coimbra
# EM: 1
# F1: 1.0
#
#
# Question: What was the major loss for Prussia at Hochkirch?
# Prediction: decisive breakthrough
# True Answer: lost much of his artillery
# EM: 0
# F1: 0
#
#
# 0.3456559215176269
